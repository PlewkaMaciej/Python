# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
np1= np.array([1,2,3,4])
np2=np.array([[1,2,0],[3,5,8]])
np2.shape
# Out:
# (2, 3)

# %%
data2 = pd.read_csv("../Customer.csv",header=0,index_col=0)
# data2["Segment"]=data2["Segment"].replace({"Consumer":0,"Corporate":1,"Home Office":2})
def replaceNumber(data):
    for column in data.columns:
        if len(data[column].unique()) < 4:
            uniqueData = data[column].unique()
            newValues = {}
            print(uniqueData)
            i=0
            for x in uniqueData:
                i=i+1
                newValues[x]= i
            data[column] = data[column].replace(newValues)
replaceNumber(data2)
print(data2)
# Out:
# ['Consumer' 'Corporate' 'Home Office']
# ['United States']
#                  Customer Name  Segment  Age  Country               City  \
# Customer ID
# CG-12520           Claire Gute        1   67        1          Henderson
# DV-13045       Darrin Van Huff        2   31        1        Los Angeles
# SO-20335        Sean O'Donnell        1   65        1    Fort Lauderdale
# BH-11710       Brosina Hoffman        1   20        1        Los Angeles
# AA-10480          Andrew Allen        1   50        1            Concord
# ...                        ...      ...  ...      ...                ...
# CJ-11875          Carl Jackson        2   64        1       Philadelphia
# RS-19870            Roy Skaria        3   39        1         Burlington
# SC-20845            Sung Chung        1   69        1  Arlington Heights
# RE-19405       Ricardo Emerson        1   35        1               Kent
# SM-20905     Susan MacKendrick        1   46        1             Newark
#
# ...

# %%
sns.distplot(data2.Age)
# Out:
# C:\Users\plewk\AppData\Local\Temp\ipykernel_10484\3648917453.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data2.Age)
# <Axes: xlabel='Age', ylabel='Density'>
